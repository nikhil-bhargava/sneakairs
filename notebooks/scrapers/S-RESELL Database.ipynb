# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.keys import Keys

# %%
df = pd.read_csv('KOF_04152019.csv')

# %%
shoes = list(df.Code_Style)

# %%
#update driver here: http://chromedriver.chromium.org/downloads
driver = webdriver.Chrome(executable_path='/Users/nikhilbhargava/Documents/Shtocks/Selenium/chromedriver')

# %%
driver.get("https://stockx.com/")

# %%
html = []
id_html = {}

for i in range(len(shoes)):
    try:
        shoe = shoes[i]
        url = 'https://stockx.com/search?s=' + str(shoe)
        driver.get(url)
        driver.find_element_by_css_selector('#search-wrapper > div.search-results-grid > div:nth-child(1) > a > h4').click()
        #search-wrapper > div.search-results-grid > div:nth-child(1) > a > h4
        soupMain = BeautifulSoup(driver.page_source, 'html.parser')
        
        
        id_html[shoe] = soupMain
        html.append(soupMain)
    except:
        id_html[shoe] = ''
        html.append('')
    if (i%100==0):
        print('Finished scraping the', str(i) + 'th/st shoe.')
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300

# %%
file = open("resale-list-2.txt", "w") 
yes = str(html)
file.write(yes)
file.close()

# %%
file = open("resale-dict-2.txt", "w") 
yes = str(id_html)
file.write(yes) 
file.close()

# %%
html[7]
# Out:
# <html class="wf-proximanova-n9-active wf-proximanova-i9-active wf-proximanova-n7-active wf-proximanova-i7-active wf-proximanova-n8-active wf-proximanova-i8-active wf-proximanova-n6-active wf-proximanova-n4-active wf-proximanova-i4-active wf-proximanova-n3-active wf-proximanova-n5-active wf-bebasneue-n4-active wf-active" lang="en"><head>
# <title>StockX: Buy and Sell Sneakers, Streetwear, Handbags, Watches</title>
# <link href="https://web-assets.stockx.com/style.app.bundle.d0b3b33bd6e0ff2d09d61f4af2f5d30295358c17.css" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha384-wvfXpqpZZVQGK6TAh5PVlGOfQNHSoD2xbE+QkPxCAFlNEevoEH3Sl0sibVcOQVnN" rel="stylesheet"/>
# <link href="https://stockx-assets.imgix.net/logo/favicon.ico?auto=compress" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://stockx-assets.imgix.net/logo/favicon.ico?auto=compress" rel="icon" type="image/x-icon"/>
# ...

# %%
url = 'https://stockx.com/nike-lebron-icon-john-elliott-black'
responseMain = requests.get(url)
soupMain = BeautifulSoup(responseMain.text, 'html.parser')

# %%
soupMain
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>LeBron Icon John Elliott Black - AQ0114-001</title>
# <link href="https://web-assets.stockx.com/style.app.bundle.d0b3b33bd6e0ff2d09d61f4af2f5d30295358c17.css" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha384-wvfXpqpZZVQGK6TAh5PVlGOfQNHSoD2xbE+QkPxCAFlNEevoEH3Sl0sibVcOQVnN" rel="stylesheet"/>
# <link href="https://stockx-assets.imgix.net/logo/favicon.ico?auto=compress" rel="shortcut icon" type="image/x-icon">
# <link href="https://stockx-assets.imgix.net/logo/favicon.ico?auto=compress" rel="icon" type="image/x-icon"/>
# <link href="/manifest.json" rel="manifest"/>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# ...
